# %%
from test import *
# Out:
# Model:
# ---------------------
# Linear (2, 25)
# ReLU
# Linear (25, 25)
# ReLU
# Linear (25, 25)
# ReLU
# Linear (25, 2)
#
# MSE Loss
# ---------------------
# Epoch 0 | Loss 51.80
# Epoch 1 | Loss 49.96
# Epoch 2 | Loss 48.34
# Epoch 3 | Loss 43.76
# Epoch 4 | Loss 35.66
# Epoch 5 | Loss 26.60
# Epoch 6 | Loss 21.22
# Epoch 7 | Loss 19.05
# Epoch 8 | Loss 17.32
# Epoch 9 | Loss 16.96
# Epoch 10 | Loss 16.01
# Epoch 11 | Loss 15.31
# Epoch 12 | Loss 14.81
# Epoch 13 | Loss 14.25
# Epoch 14 | Loss 13.62
# Epoch 15 | Loss 13.49
# Epoch 16 | Loss 13.21
# Epoch 17 | Loss 13.15
# Epoch 18 | Loss 12.57
# Epoch 19 | Loss 12.24
# Epoch 20 | Loss 11.76
# Epoch 21 | Loss 11.81
# Epoch 22 | Loss 11.68
# Epoch 23 | Loss 11.87
# Epoch 24 | Loss 11.33
# Train accuracy: 0.973 | Test accuracy: 0.979
