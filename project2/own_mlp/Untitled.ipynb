# %%
from test import *
# Out:
# Model:
# ---------------------
# Linear (2, 25)
# ReLU
# Linear (25, 25)
# ReLU
# Linear (25, 25)
# ReLU
# Linear (25, 2)
# MSE Loss
# ---------------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-c5e37e8df2a0> in <module>
# ----> 1 from test import *
#
# ~/Documents/EPFL/_MA2/Deep Learning/deep-learning-projects/project2/own_mlp/test.py in <module>
#      73     print("Train accuracy: {} | Test accuracy: {}".format(train_acc, test_acc))
#      74
# ---> 75 test()
#
# ~/Documents/EPFL/_MA2/Deep Learning/deep-learning-projects/project2/own_mlp/test.py in test()
#      65
#      66     # train model
# ---> 67     model.train(train_inputs, train_targets, epochs=25, batch_size=10, verbose=True)
#      68
#      69     # compute accuracy
#
# ...
